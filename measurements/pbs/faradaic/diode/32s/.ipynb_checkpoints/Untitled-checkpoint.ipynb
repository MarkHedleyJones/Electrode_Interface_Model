# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
import os, sys
files = [x for x in os.listdir('.') if x[-4:] == '.npy']
for file in files:
    print(file)
    data = np.load(file)
    plt.plot(data['time'], data['current'])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 1.0X-PBS.npy
# 0.5X-PBS.npy
# 0.25X-PBS.npy

# %%
path = '../128s'
files = [x for x in os.listdir(path) if x[-4:] == '.npy']
for file in files:
    print(file)
    data = np.load(path + '/' + file)
    plt.plot(data['time'], data['current'])
# Out:
# 0.025X-PBS.npy
# 1.0X-PBS.npy
# 0.05X-PBS.npy
# 0.1X-PBS.npy
# 0.5X-PBS.npy
# 0.25X-PBS.npy

# %%
path = '../600s'
files = [x for x in os.listdir(path) if x[-4:] == '.npy']
for file in files:
    print(file)
    data = np.load(path + '/' + file)
    plt.plot(data['time'], data['current'])
# Out:
# 0.025X-PBS.npy
# 1.0X-PBS.npy
# 0.05X-PBS.npy
# 0.5X-PBS.npy
# 0.25X-PBS.npy
